# %%
import lib1

print(lib1.l1)
# Out:
# 1

# %%
lib1.fun1()
c1 = lib1.cl()
print(c1)
# Out:
# fun1
# 객체생성 !!!
# ...

# %%
import random
from pylab import *

# %%
print(random.randint(1, 100))
# Out:
# 93

# %%
t = arange(0.0, 2.0, 0.01)
s = sin(2 * pi * t)
plot(t,s)
grid(True)
show()
