# %% [markdown]
# 1. 인공지능 모형과 학습
#
# 1). 커널
#
# 2). 바이어스 (bias)
#
# X → W(k)    k : 커널
# (W * X + b)  /  W와 b가 바뀐다.
#
# 학습 → 가중치가 바뀐다 → 가중치가 초기에 무작위로 부여
# → 목표에 맞게 가중치 수정
#
# CNN은 Computer Vision에서 활용
# Convolution Layer → 2차원 데이터를 받음(공간정보 유지)
# [기타 Neural Network의 경우는 1차원 벡터 형태로 데이터 인식]
# * cnn explainer 참고
#
# 2. CNN 구성
#
# 1). Con Layer
#
# 2). Max Pooling Layer
#
# **** 특징을 추출하는 구간  /  분류하는 구간 ****
#
#
# 예시 : (64,64,3) 64 * 64 픽셀, RGB 3개 채널로 구성된 이미지
# STRIDE → 보폭  /  Convolution → 3*3 픽셀을 가지고 가중치 행렬과 벡터곱
#                  → 하나의 픽셀로 표현
#
# 3. RELU  /  활성화 함수의 일종
#
# x = 0 (where x <= 0)
# x = y (where x > 0)
#
# 4. Max Pooling
#
# Pooling Layer  /  max, average
#
# 예시 : 60X60 → 30X30  /  데이터를 날려버림
#        2X2 커널 구성, 거기서 가장 큰 값만 남김 → Max Pooling
#
# 데이터 손실에도 불구하고 불필요한 부분 등을 과감히 제거  /  압축
# DL → 관계 없는 것도 관계가 있다고 학습해버리기 때문
# (Conv + Relu) → (Conv + Relu) + Max_Pool → (Conv + Relu) → (Conv + Relu) + Max_Pool
#
# 5. Dense Layer
#
# activation(dot(x,y) + b)
#
#  1). 분류
#  2). 회귀
#
# soft max  /  확률
# 사상(mapping)
#
# 6. Dropout
#
# 학습률 낮춤  /  학습시 층간 연결을 일정 비율로 무작위로 단절 시킴  /
# 쓸데없는 특징들이 연결되는 것을 방지 → 예측 능력 상승
